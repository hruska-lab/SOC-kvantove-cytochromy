# %%
# !pip install rdkit
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True

def mol_with_atom_index( mol ):
    atoms = mol.GetNumAtoms()
    for idx in range( atoms ):
        mol.GetAtomWithIdx( idx ).SetProp( 'molAtomMapNumber', str( mol.GetAtomWithIdx( idx ).GetIdx() ) )
    return mol

# %%
from rdkit.Chem.Draw import rdMolDraw2D
from rdkit.Chem import rdDetermineBonds
from rdkit.Chem import rdDepictor
from rdkit import Chem
from rdkit.Chem import (
    AllChem,
    rdCoordGen,
)

# %%
mol = Chem.MolFromXYZFile('new_localmin_1.xyz')
rdDetermineBonds.DetermineConnectivity(mol)
rdDepictor.SetPreferCoordGen(True)
mol.GetAtomWithIdx(19).SetProp('atomNote', '1')
mol.GetAtomWithIdx(20).SetProp('atomNote', '2')
mol.GetAtomWithIdx(21).SetProp('atomNote', '3')
mol.GetAtomWithIdx(22).SetProp('atomNote', '4')
mol.GetAtomWithIdx(23).SetProp('atomNote', '5')
mol.GetAtomWithIdx(24).SetProp('atomNote', '6')
mol.GetAtomWithIdx(25).SetProp('atomNote', '7')
mol.GetAtomWithIdx(26).SetProp('atomNote', '8')
mol.GetAtomWithIdx(27).SetProp('atomNote', '9')
mol.GetAtomWithIdx(28).SetProp('atomNote', '10')
mol.GetAtomWithIdx(29).SetProp('atomNote', '11')
mol

# %%
AllChem.Compute2DCoords(mol)
# Out:
# 0

# %%
Draw.MolToFile(mol, 'atom_annotation_1.png')
